# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from keras.datasets import boston_housing
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation

# %%
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
print(x_train.shape) #13 cột (13 đặc tính vào), 404 hàng(404 mẫu)
print(y_train.shape) 
print(x_test.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (404,)
# (102, 13)
# (102,)

# %%
'''sc = StandardScaler()
sc.fit(x_train)
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)'''
# Out:
# 'sc = StandardScaler()\nsc.fit(x_train)\nx_train = sc.transform(x_train)\nx_test = sc.transform(x_test)'

# %%
model = Sequential()
model.add(Dense(50, Activation('relu'), input_shape=(13,)))
model.add(Dense(20, Activation('relu')))
model.add(Activation('linear'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 50)                700
#
#  dense_13 (Dense)            (None, 20)                1020
#
#  activation_15 (Activation)  (None, 20)                0
#
# =================================================================
# Total params: 1,720
# Trainable params: 1,720
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='mean_absolute_error', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=1000, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1/1 [==============================] - 1s 861ms/step - loss: 22.2182 - accuracy: 0.0050 - val_loss: 22.9017 - val_accuracy: 0.0098
# Epoch 2/10
# 1/1 [==============================] - 0s 50ms/step - loss: 22.2089 - accuracy: 0.0050 - val_loss: 22.8925 - val_accuracy: 0.0098
# Epoch 3/10
# 1/1 [==============================] - 0s 51ms/step - loss: 22.1993 - accuracy: 0.0050 - val_loss: 22.8830 - val_accuracy: 0.0098
# Epoch 4/10
# 1/1 [==============================] - 0s 59ms/step - loss: 22.1895 - accuracy: 0.0050 - val_loss: 22.8734 - val_accuracy: 0.0098
# Epoch 5/10
# 1/1 [==============================] - 0s 72ms/step - loss: 22.1795 - accuracy: 0.0050 - val_loss: 22.8634 - val_accuracy: 0.0098
# Epoch 6/10
# 1/1 [==============================] - 0s 78ms/step - loss: 22.1692 - accuracy: 0.0050 - val_loss: 22.8532 - val_accuracy: 0.0098
# Epoch 7/10
# 1/1 [==============================] - 0s 66ms/step - loss: 22.1586 - accuracy: 0.0050 - val_loss: 22.8427 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 0s 48ms/step - loss: 22.1477 - accuracy: 0.0050 - val_loss: 22.8320 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 0s 66ms/step - loss: 22.1365 - accuracy: 0.0050 - val_loss: 22.8210 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 1/1 [==============================] - 0s 41ms/step - loss: 22.1250 - accuracy: 0.0050 - val_loss: 22.8097 - val_accuracy: 0.0000e+00
