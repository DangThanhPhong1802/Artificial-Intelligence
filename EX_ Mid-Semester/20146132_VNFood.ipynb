# %% [markdown]
# **KHAI BÁO THƯ VIỆN**

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.optimizers import SGD, RMSprop
from keras.models import Sequential, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import np_utils, to_categorical, load_img, img_to_array
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten, LeakyReLU

from sklearn import preprocessing
from sklearn.utils import validation
from sklearn.model_selection import train_test_split

# %% [markdown]
# **GỌI THƯ MỤC CHỨA ẢNH**

# %%
# %cd /content/drive/MyDrive/VNFoodIMG
# Out:
# /content/drive/MyDrive/VNFoodIMG

# %% [markdown]
# **ImageDataGenerator : Giúp tải và gắn nhãn các tập dữ liệu hình ảnh. Tạo hai đối tượng cho ImageDataGenerator và cũng thay đổi tỷ lệ hình ảnh sao cho giá trị pixel của chúng được chuẩn hóa từ 0 đến 1 (bằng cách chia cho 255). RGB có 8 bit cho mỗi kênh màu. Phạm vi cho mỗi màu riêng lẻ là 0–255 (như 2⁸ = 256 khả năng). Vì vậy, bằng cách chia cho 255, phạm vi 0–255 có thể được mô tả với phạm vi 0,0–1,0 trong đó 0,0 có nghĩa là 0 (0x00) và 1,0 có nghĩa là 255 (0xFF)**

# %% [markdown]
# **flow_from_directory : chỉ định đường dẫn đến các thư mục huấn luyện và kiểm tra**

# %%
Data = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
Train = Data.flow_from_directory('/content/drive/MyDrive/VNFoodIMG', target_size=(150,150),batch_size=32, class_mode='categorical')
Train.class_indices
# Out:
# Found 300 images belonging to 10 classes.
# {'BanhChung': 0,
#  'BanhKhot': 1,
#  'BanhMi': 2,
#  'BanhXeo': 3,
#  'ChaGio': 4,
#  'ComTam': 5,
#  'GoiCuon': 6,
#  'MiQuang': 7,
#  'Pho': 8,
#  'ThitKhoTau': 9}

# %%
#Tạo mô hình Sequential
model=Sequential()

# Tạo lớp Convolution với bộ lọc 3x3, activation là hàm phi tuyến
'''Conv2D (): 
- Mạng nơ-ron áp dụng bộ lọc cho hình ảnh đầu vào để tạo bản đồ đặc trưng tóm tắt sự hiện diện 
của các tính năng hoặc mẫu được phát hiện trong đầu vào. Trong trường hợp của chúng ta, có 32, 64, 128 và 128 bộ lọc
- Tăng số lượng bộ lọc trên mỗi lớp vì khi di chuyển về phía trước trong các lớp, các mẫu trở nên phức tạp hơn; 
do đó có nhiều sự kết hợp của các mẫu để chụp. Vì vậy, tăng kích thước bộ lọc trong các lớp tiếp theo để thu được nhiều kết hợp nhất có thể'''

'''MaxPool2D (): 
- Tổng hợp tối đa là thao tác gộp chọn phần tử lớn nhất từ ​​vùng của bản đồ đối tượng được bộ lọc bao phủ
- Nói một cách đơn giản trong Max pooling, chọn giá trị lớn nhất trong ma trận để giảm kích thước hình ảnh 
mà không làm mất thông tin hình ảnh'''

'''Flatten (): Chuyển đổi mảng dữ liệu hình ảnh đa chiều thành mảng một chiều'''

'''Dense (): Lớp mạng nơ-ron được kết nối đầy đủ trong đó mỗi nút đầu vào được kết nối với mỗi nút đầu ra'''

model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(10,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 256)               10617088
#
#  dropout (Dropout)           (None, 256)               0
#
#  leaky_re_lu (LeakyReLU)     (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 10,712,906
# Trainable params: 10,712,906
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **BIÊN DỊCH**

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
train=model.fit(Train, epochs=50, batch_size=256, verbose=1)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 67s 6s/step - loss: 11.2914 - accuracy: 0.1000
# Epoch 2/50
# 10/10 [==============================] - 23s 2s/step - loss: 2.2297 - accuracy: 0.1700
# Epoch 3/50
# 10/10 [==============================] - 21s 2s/step - loss: 1.8923 - accuracy: 0.2933
# Epoch 4/50
# 10/10 [==============================] - 21s 2s/step - loss: 1.6083 - accuracy: 0.4167
# Epoch 5/50
# 10/10 [==============================] - 21s 2s/step - loss: 1.4267 - accuracy: 0.4533
# Epoch 6/50
# 10/10 [==============================] - 23s 2s/step - loss: 1.2308 - accuracy: 0.6100
# Epoch 7/50
# 10/10 [==============================] - 22s 2s/step - loss: 1.1627 - accuracy: 0.5767
# Epoch 8/50
# 10/10 [==============================] - 21s 2s/step - loss: 1.1707 - accuracy: 0.6000
# Epoch 9/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.9709 - accuracy: 0.6600
# Epoch 10/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.8462 - accuracy: 0.7000
# Epoch 11/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.7084 - accuracy: 0.7700
# Epoch 12/50
# 10/10 [==============================] - 20s 2s/step - loss: 0.6361 - accuracy: 0.7800
# Epoch 13/50
# 10/10 [==============================] - 20s 2s/step - loss: 0.5440 - accuracy: 0.8167
# Epoch 14/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.5241 - accuracy: 0.8200
# Epoch 15/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.4608 - accuracy: 0.8600
# Epoch 16/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.3394 - accuracy: 0.9033
# Epoch 17/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.3878 - accuracy: 0.8533
# Epoch 18/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.3773 - accuracy: 0.8800
# Epoch 19/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.2983 - accuracy: 0.9133
# Epoch 20/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.2492 - accuracy: 0.9267
# Epoch 21/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.1938 - accuracy: 0.9533
# Epoch 22/50
# 10/10 [==============================] - 20s 2s/step - loss: 0.2153 - accuracy: 0.9267
# Epoch 23/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.1608 - accuracy: 0.9467
# Epoch 24/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.1556 - accuracy: 0.9567
# Epoch 25/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.1650 - accuracy: 0.9633
# Epoch 26/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.1282 - accuracy: 0.9567
# Epoch 27/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.2860 - accuracy: 0.9200
# Epoch 28/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.2020 - accuracy: 0.9600
# Epoch 29/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.1176 - accuracy: 0.9633
# Epoch 30/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.1304 - accuracy: 0.9633
# Epoch 31/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.1105 - accuracy: 0.9700
# Epoch 32/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0754 - accuracy: 0.9833
# Epoch 33/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0519 - accuracy: 0.9900
# Epoch 34/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0632 - accuracy: 0.9800
# Epoch 35/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.1177 - accuracy: 0.9533
# Epoch 36/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.1057 - accuracy: 0.9533
# Epoch 37/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0837 - accuracy: 0.9767
# Epoch 38/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.1165 - accuracy: 0.9733
# Epoch 39/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.1049 - accuracy: 0.9600
# Epoch 40/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0674 - accuracy: 0.9767
# Epoch 41/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0673 - accuracy: 0.9867
# Epoch 42/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0546 - accuracy: 0.9800
# Epoch 43/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0597 - accuracy: 0.9833
# Epoch 44/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0888 - accuracy: 0.9733
# Epoch 45/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0477 - accuracy: 0.9800
# Epoch 46/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0895 - accuracy: 0.9700
# Epoch 47/50
# 10/10 [==============================] - 29s 3s/step - loss: 0.1015 - accuracy: 0.9700
# Epoch 48/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0800 - accuracy: 0.9800
# Epoch 49/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0604 - accuracy: 0.9833
# Epoch 50/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0427 - accuracy: 0.9933

# %% [markdown]
# **ĐÁNH GIÁ ĐỘ CHÍNH XÁC VÀ ĐỘ MẤT MÁT**

# %%
Score=model.evaluate(Train,verbose=0)
print('Hàm Mất Mát Trên Tập Kiểm Tra : ', Score[0])
print('Độ Chính Xác Trên Tập Kiểm Tra : ', Score[1])
# Out:
# Hàm Mất Mát Trên Tập Kiểm Tra :  0.022159531712532043
# Độ Chính Xác Trên Tập Kiểm Tra :  1.0

# %%
fig,axes = plt.subplots(1,2, figsize=(15,8))
fig.suptitle("The model 's evaluation ",fontsize=20)

axes[0].plot(train.history['loss'])
axes[0].set_title('Model Loss')
axes[0].set_ylabel('Loss')
axes[0].set_xlabel('Epoch')
axes[0].legend(['Data'])

axes[1].plot(train.history['accuracy'])
axes[1].set_title('Model Accuracy')
axes[1].set_ylabel('Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].legend(['Train'])
plt.show()

# %% [markdown]
# **LƯU DỮ LIỆU VỪA TRAIN**

# %%
model.save('/content/drive/MyDrive/Saved_Train/20146132_VNFood.h5')

# %% [markdown]
# **LẤY DỮ LIỆU VỪA TRAIN ĐỂ BẮT ĐẦU NHẬN DIỆN**

# %%
model_1 = load_model('/content/drive/MyDrive/Saved_Train/20146132_VNFood.h5')

# %% [markdown]
# **NHẬN DIỆN**

# %%
folder='/content/drive/MyDrive/Test/20146132_VNFood/'
for i in os.listdir(folder):
  img=load_img(folder+i, target_size=(150,150))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  result=(model_1.predict(img).argmax())
  class_name=['BanhChung', 'BanhKhot', 'BanhMi', 'BanhXeo', 'ChaGio', 'ComTam', 'GoiCuon', 'MiQuang', 'Pho', 'ThitKhoTau']
  print('Đây là món : {}'.format(class_name[result]))
  plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
